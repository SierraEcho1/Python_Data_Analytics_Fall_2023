# %%
#Python Class Project 2 - Analysis of Dibetes Data

# %%
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %%
import matplotlib.pyplot as plot
# %matplotlib inline
import numpy as np
import seaborn as sns

# %%
df.shape
# Out:
# (101766, 50)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#Ran a head function again to confirm Weight column is missing values
df.head(25)
# Out:
#     encounter_id  patient_nbr             race  gender       age weight  \
# 0        2278392      8222157        Caucasian  Female    [0-10)      ?
# 1         149190     55629189        Caucasian  Female   [10-20)      ?
# 2          64410     86047875  AfricanAmerican  Female   [20-30)      ?
# 3         500364     82442376        Caucasian    Male   [30-40)      ?
# 4          16680     42519267        Caucasian    Male   [40-50)      ?
# 5          35754     82637451        Caucasian    Male   [50-60)      ?
# 6          55842     84259809        Caucasian    Male   [60-70)      ?
# 7          63768    114882984        Caucasian    Male   [70-80)      ?
# 8          12522     48330783        Caucasian  Female   [80-90)      ?
# 9          15738     63555939        Caucasian  Female  [90-100)      ?
# 10         28236     89869032  AfricanAmerican  Female   [40-50)      ?
# 11         36900     77391171  AfricanAmerican    Male   [60-70)      ?
# ...

# %%
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
df.count()
# Out:
# encounter_id                101766
# patient_nbr                 101766
# race                        101766
# gender                      101766
# age                         101766
# weight                      101766
# admission_type_id           101766
# discharge_disposition_id    101766
# admission_source_id         101766
# time_in_hospital            101766
# payer_code                  101766
# medical_specialty           101766
# num_lab_procedures          101766
# num_procedures              101766
# num_medications             101766
# number_outpatient           101766
# number_emergency            101766
# number_inpatient            101766
# diag_1                      101766
# diag_2                      101766
# diag_3                      101766
# number_diagnoses            101766
# max_glu_serum                 5346
# A1Cresult                    17018
# metformin                   101766
# repaglinide                 101766
# nateglinide                 101766
# ...

# %%
#Removing missing values from data set
missing_values=["na","n/a","--"]
df=pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv', na_values=missing_values)

# %%
#Output of removed missing values. Do not see a change in data set
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
#Drop column with missing values
drop_cols = ['weight']

# %%
df1=df.drop(drop_cols, axis=1)

# %%
#Output of data with removed "Weight" column
df1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 0            2278392      8222157        Caucasian  Female   [0-10)
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                       6                        25                    1
# ...

# %%
#Race taking the most medication
sns.jointplot(x='race', y='num_medications', data=df1)

# %%
#Create data subset 
df2=df[['race', 'gender','age','num_medications']]

# %%
#Output of new data set 
df2
# Out:
#                    race  gender      age  num_medications
# 0             Caucasian  Female   [0-10)                1
# 1             Caucasian  Female  [10-20)               18
# 2       AfricanAmerican  Female  [20-30)               13
# 3             Caucasian    Male  [30-40)               16
# 4             Caucasian    Male  [40-50)                8
# ...                 ...     ...      ...              ...
# 101761  AfricanAmerican    Male  [70-80)               16
# 101762  AfricanAmerican  Female  [80-90)               18
# 101763        Caucasian    Male  [70-80)                9
# 101764        Caucasian  Female  [80-90)               21
# 101765        Caucasian    Male  [70-80)                3
#
# [101766 rows x 4 columns]

# %%
df2=df2.rename(columns={'race': 'Race','gender': 'Gender','age': 'Age','num_medications': 'Number of Rx'})

# %%
#Rename of columns
df2
# Out:
#                    Race  Gender      Age  Number of Rx
# 0             Caucasian  Female   [0-10)             1
# 1             Caucasian  Female  [10-20)            18
# 2       AfricanAmerican  Female  [20-30)            13
# 3             Caucasian    Male  [30-40)            16
# 4             Caucasian    Male  [40-50)             8
# ...                 ...     ...      ...           ...
# 101761  AfricanAmerican    Male  [70-80)            16
# 101762  AfricanAmerican  Female  [80-90)            18
# 101763        Caucasian    Male  [70-80)             9
# 101764        Caucasian  Female  [80-90)            21
# 101765        Caucasian    Male  [70-80)             3
#
# [101766 rows x 4 columns]

# %%
#Average number of Rx taken by patient
df2["Number of Rx"].mean()
# Out:
# 16.021844230882614

# %%
#Comparison point - Number of Rx by Race
df2.groupby(['Race'])['Number of Rx'].count().sort_values(ascending=False)
# Out:
# Race
# Caucasian          76099
# AfricanAmerican    19210
# ?                   2273
# Hispanic            2037
# Other               1506
# Asian                641
# Name: Number of Rx, dtype: int64

# %%
#Graph of comparison point

df2.groupby(['Race'])['Number of Rx'].count().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Race'>

# %%
#Shows most patients take b/w 10-20 Rx
sns.displot(df2['Number of Rx'])
# Out:
# C:\Users\eliss\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df2.hist('Number of Rx')
# Out:
# array([[<Axes: title={'center': 'Number of Rx'}>]], dtype=object)

# %%
df2.groupby(['Gender'])['Number of Rx'].count().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Gender'>

# %%
df3=df2.groupby(['Gender'])['Number of Rx'].count()

# %%
df3
# Out:
# Gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: Number of Rx, dtype: int64

# %%
#African American Comparison point
df4=df2[df2['Race'].str.contains('Afric')]

# %%
df4
# Out:
#                    Race  Gender       Age  Number of Rx
# 2       AfricanAmerican  Female   [20-30)            13
# 10      AfricanAmerican  Female   [40-50)            17
# 11      AfricanAmerican    Male   [60-70)            11
# 14      AfricanAmerican  Female   [60-70)             2
# 15      AfricanAmerican    Male   [60-70)            13
# ...                 ...     ...       ...           ...
# 101739  AfricanAmerican    Male   [70-80)            14
# 101741  AfricanAmerican    Male  [90-100)             8
# 101760  AfricanAmerican  Female   [60-70)            25
# 101761  AfricanAmerican    Male   [70-80)            16
# 101762  AfricanAmerican  Female   [80-90)            18
#
# [19210 rows x 4 columns]

# %%
df4=df2[df2['Race'].str.contains('Afric')].plot(kind='line')

# %%
sns.barplot(x='Gender', y='Number of Rx', data=df4)
# Out:
# <Axes: xlabel='Gender', ylabel='Number of Rx'>

# %%
#Analysis
My goal with this project was to evaluate the number of percriptions taken by race and gender in the Diabetes dataset. 
Initial data showed that caucasians took more perscriptions than any other group within the dataset and that the average number of perscriptions taken by a patient was 16. 
Next, I wanted to compare the number of perscriptions taken by gender. In both the larger dataset (all groups included) and the subset (African American) women took more perscriptions then men. 
This result of this information could be based on how often visit their medical providers and seek treatment as opposed to men.
