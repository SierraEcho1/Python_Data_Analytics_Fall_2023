# %%
#Import panda library and raw data
import pandas as pd
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#Import graphs
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
df.shape
# Out:
# (212331, 15)

# %%
df.columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# 3  Common Core Algebra  2016             3          s                       s
# 4  Common Core Algebra  2017             2          s                       s
#
#   Percent Scoring Below 65 Number Scoring 65 or Above  \
# 0                        s                          s
# ...

# %%
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
# Grouped by Regents Exam Type in ascending order
df.groupby(['Regents Exam'])['Total Tested'].count().sort_values(ascending=False)
# Out:
# Regents Exam
# Common Core Algebra                29254
# Living Environment                 25539
# U.S. History and Government        20426
# Common Core English                19878
# Global History and Geography       19192
# Physical Settings/Earth Science    15971
# Common Core Geometry               15267
# Physical Settings/Chemistry        11670
# English                            11091
# Integrated Algebra                 11022
# Algebra2/Trigonometry              10788
# Geometry                            8509
# Common Core Algebra2                7915
# Physical Settings/Physics           5799
# Name: Total Tested, dtype: int64

# %%
#Describe of complete data set
df.groupby(['Year'])['Mean Score'].describe()
# Out:
#       count unique top   freq
# Year
# 2015  72768    725   s  24837
# 2016  76123    700   s  29059
# 2017  63440    667   s  21326

# %%
df.groupby(['Regents Exam'])['Total Tested'].count().sort_values(ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Regents Exam'>

# %%
#Attempted to create visualization but was unable to manipulate axes.
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#Attempt at displaying a visualization by test year.
df.plot(kind="scatter", x='Total Tested', y='Year')
# Out:
# <Axes: xlabel='Total Tested', ylabel='Year'>

# %%
#Filter Rows
#Fuzzy Matching
#Filtered data by school specific name - Springfield Gardens
df[df['School Name'].str.contains('Springfield')]
# Out:
#        School DBN                   School Name  \
# 15864      29Q059  I.S. 059 Springfield Gardens
# 15865      29Q059  I.S. 059 Springfield Gardens
# 15866      29Q059  I.S. 059 Springfield Gardens
# 15867      29Q059  I.S. 059 Springfield Gardens
# 15868      29Q059  I.S. 059 Springfield Gardens
# ...           ...                           ...
# 199866     29Q059  I.S. 059 Springfield Gardens
# 199867     29Q059  I.S. 059 Springfield Gardens
# 199868     29Q059  I.S. 059 Springfield Gardens
# 199869     29Q059  I.S. 059 Springfield Gardens
# 199870     29Q059  I.S. 059 Springfield Gardens
#
#                            School Level                 Regents Exam  Year  \
# 15864   Junior High-Intermediate-Middle          Common Core Algebra  2015
# 15865   Junior High-Intermediate-Middle          Common Core Algebra  2016
# 15866   Junior High-Intermediate-Middle          Common Core Algebra  2017
# 15867   Junior High-Intermediate-Middle           Living Environment  2015
# ...

# %%
#Created new data set for Jr. high schools & Common Core Algebra exam.
df2=df[(df['School Level']=="Junior High-Intermediate-Middle")&(df["Regents Exam"]=="Common Core Algebra")]

# %%
df2.shape
# Out:
# (6420, 15)

# %%
#Output of Jr. high & Common Core Algebra subset
df2.head()
# Out:
#    School DBN                                        School Name  \
# 50     01M301              Technology, Arts, and Sciences Studio
# 51     01M301              Technology, Arts, and Sciences Studio
# 53     01M332              University Neighborhood Middle School
# 54     01M345  Collaborative Academy of Science, Technology, ...
# 55     01M378                          School for Global Leaders
#
#                        School Level         Regents Exam  Year  Total Tested  \
# 50  Junior High-Intermediate-Middle  Common Core Algebra  2016             4
# 51  Junior High-Intermediate-Middle  Common Core Algebra  2017             1
# 53  Junior High-Intermediate-Middle  Common Core Algebra  2017             1
# 54  Junior High-Intermediate-Middle  Common Core Algebra  2016             3
# 55  Junior High-Intermediate-Middle  Common Core Algebra  2015             6
#
#    Mean Score Number Scoring Below 65 Percent Scoring Below 65  \
# ...

# %%
#Remove Columns 
drop_cols = ['Number Scoring CR','Percent Scoring CR']

# %%
#Remove columns from Springfield Gardens subset 
df3 = df2.drop(drop_cols, axis=1)

# %%
#Out put with removed columns
df3
# Out:
#        School DBN                                        School Name  \
# 50         01M301              Technology, Arts, and Sciences Studio
# 51         01M301              Technology, Arts, and Sciences Studio
# 53         01M332              University Neighborhood Middle School
# 54         01M345  Collaborative Academy of Science, Technology, ...
# 55         01M378                          School for Global Leaders
# ...           ...                                                ...
# 210797     84R073               New World Preparatory Charter School
# 210798     84R073               New World Preparatory Charter School
# 210801     84X177                           Mott Hall Charter School
# 210802     84X177                           Mott Hall Charter School
# 210803     84X177                           Mott Hall Charter School
#
#                            School Level         Regents Exam  Year  \
# 50      Junior High-Intermediate-Middle  Common Core Algebra  2016
# ...

# %%
#Remove Rows
df4 = df3.dropna()

# %%
df4
# Out:
#        School DBN                                        School Name  \
# 50         01M301              Technology, Arts, and Sciences Studio
# 51         01M301              Technology, Arts, and Sciences Studio
# 53         01M332              University Neighborhood Middle School
# 54         01M345  Collaborative Academy of Science, Technology, ...
# 55         01M378                          School for Global Leaders
# ...           ...                                                ...
# 210797     84R073               New World Preparatory Charter School
# 210798     84R073               New World Preparatory Charter School
# 210801     84X177                           Mott Hall Charter School
# 210802     84X177                           Mott Hall Charter School
# 210803     84X177                           Mott Hall Charter School
#
#                            School Level         Regents Exam  Year  \
# 50      Junior High-Intermediate-Middle  Common Core Algebra  2016
# ...

# %%
df4.groupby(['Regents Exam'])['Total Tested'].count()
# Out:
# Regents Exam
# Common Core Algebra    6420
# Name: Total Tested, dtype: int64

# %%
#Describe of Springfield subset
df4.groupby(['Year'])['Mean Score'].describe()
# Out:
#      count unique top  freq
# Year
# 2015  1966    307   s   844
# 2016  2094    295   s   935
# 2017  2360    361   s  1020

# %%
#visualization of Springfield Gardens Common Core Algebra exam subset by exam year
df4.groupby(['Year'])['Mean Score'].describe().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
#Analysis
This dataset accounts for the NYC Regents Exam from 2015-2017. 
I attempted to issolate the Common Core Algebera exam results for Springfield Gardens Jr.High school to compare to citywide data.The Springfield Gardens data set was cleaned up and columns dropped however I was not able to remove the rows with no value.
